# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from os import listdir
from os.path import isfile, join

from fastai.conv_learner import *
from fastai.plots import *

# %%
PATH = 'data/humpback_whale/'

# %%
# !ls {PATH}
# Out:
# sample_submission.csv  test  train  train.csv  train.zip

# %%
train_path = f'{PATH}train'
train_files = listdir(train_path)[:4]
whale_examples = [f'{train_path}/{file}' for file in train_files
                  if isfile(join(train_path, file))]

# %%
whale_examples
# Out:
# ['data/humpback_whale/train/917c53b78.jpg',
#  'data/humpback_whale/train/5d7b60985.jpg',
#  'data/humpback_whale/train/0f6b12dc0.jpg',
#  'data/humpback_whale/train/f8a3c1402.jpg']

# %%
train_df = pd.read_csv(f'{PATH}train.csv')

# %%
train_df.set_index("Image", inplace=True)

# %%
whale_example_ids = list(train_df.loc[[file.split('/')[3] 
                                       for file in whale_examples]]['Id'])

# %%
plots_from_files(whale_examples, 
                 titles=whale_example_ids, 
                 maintitle="Multi-label classification")

# %%
from humpback import mean_average_precision

metrics = [mean_average_precision]
model = resnext50

# %%
## TODO implement mean_average_precision
## Test that it's working
# https://www.kaggle.com/pestipeti/explanation-of-map5-scoring-metric
